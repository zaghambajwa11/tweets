# %% [markdown]
# ### Apple Launched New Product **Vision Pro** I will check sentiment analysis about this product.

# %%
# Scrapping the data from twitter using snscrape
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Setting variables to be used below
maxTweets = 100000

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Vision Pro since:2023-06-01 until:2023-06-011').get_items()):
    if i>maxTweets:
        break
       
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username,])
# Out:
# /var/folders/mr/xqkrmqvj7ljfrz59pxqfk6rc0000gn/T/ipykernel_47546/1878568179.py:12: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username,])
# Empty user ref object in card on tweet 1667592273687715840
# User 2010105 not found in user refs in card on tweet 1667592273687715840
# Could not translate t.co card URL on tweet 1667575724436512769
# Empty user ref object in card on tweet 1667542250996264961
# User 2010105 not found in user refs in card on tweet 1667542250996264961
# Could not translate t.co card URL on tweet 1667537112864813057
# Unavailable user in card on tweet 1667526622814281728
# Unavailable user in card on tweet 1667526622814281728
# User 1418448802428510217 not found in user refs in card on tweet 1667526622814281728
# User 1418448802428510217 not found in user refs in card on tweet 1667526622814281728
# Could not translate t.co card URL on tweet 1667515686669672448
# ...

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# Display first 5 entries from dataframe
tweets_df2.head()
tweets_df2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Creating a dataframe from the tweets list above
# ----> 2 tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
#       4 # Display first 5 entries from dataframe
#       5 tweets_df2.head()
#
# NameError: name 'tweets_list2' is not defined

# %%
# Export dataframe into a CSV
tweets_df2.to_csv('text-query-tweets.csv', sep=',', index=False)
